# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import copy

SCALE = 256

# %% [markdown]
# # Exercise 2.1.1

# %%
# Load the grayscale image
img = cv2.imread('images/Camera Man.bmp', 0)
img_copy = copy.deepcopy(img)

# %%
# Compute the histogram using OpenCV's calcHist function
hist = [0]*SCALE
for row in img:
    for column in row:
        hist[column] += 1

hist = np.asanyarray(hist)

# Display the histogram using matplotlib
plt.plot(hist)
plt.xlim([0, SCALE])
plt.show()

# %% [markdown]
# # Exercise 2.1.2

# %%
hist_norm = hist / np.sum(hist)

# Create an array of zeros with the same shape as the histogram
intensity_transform = [0]*SCALE

intensity_transform[0] = hist_norm[0]
for i in range(1, SCALE):
    intensity_transform[i] = intensity_transform[i-1] + hist_norm[i]

intensity_transform = np.asanyarray(intensity_transform)
intensity_transform *= SCALE
for i in range(0, SCALE):
    if intensity_transform[i] - int(intensity_transform[i]) > 0.5:
        intensity_transform[i] = int(intensity_transform[i]+1)
    else:
        intensity_transform[i] = int(intensity_transform[i])

new_image = img
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        new_image[i][j] = intensity_transform[img[i][j]]
        
fig, axs = plt.subplots(1, 2, figsize=(50, 25))
axs[0].imshow(new_image, cmap='gray', vmin=0, vmax=255)
axs[0].set_title('Equalized image')

axs[1].imshow(img_copy, cmap='gray', vmin=0, vmax=255)
axs[1].set_title('original image')


plt.show()

# %%
# Load an image
elaine_img = cv2.imread('images/Elaine.bmp', cv2.IMREAD_GRAYSCALE)

# Define a noise density (i.e., the proportion of pixels to be affected by noise)
noise_density = [0.05, 0.1, 0.2, 0.4]

fig, axs = plt.subplots(2, 2, figsize=(5, 5))
j = 0.0
noisy_images = []
for i in range(len(noise_density)):
    # Generate a random mask of salt-and-pepper noise
    mask = np.random.choice((0, 1, 2), size=elaine_img.shape[:2], p=[1 - noise_density[i], noise_density[i]/2., noise_density[i]/2.])

    # Apply the mask to the image to add noise
    noisy_img = np.copy(elaine_img)
    noisy_img[mask == 1] = 255  # Salt noise
    noisy_img[mask == 2] = 0    # Pepper noise
    noisy_images.append(noisy_img)
    
    # Display the noisy image
    axs[i%2][int(j)].imshow(noisy_img, cmap='gray', vmin=0, vmax=255)
    
    j += 0.5

# %%
def median_filter(noisy_image, size):
    filtered = np.zeros_like(noisy_image)
    for i in range(noisy_image.shape[0]):
        for j in range(noisy_image.shape[1]):
            diff_i = 0
            diff_j = 0
            if (i+size) > noisy_image.shape[0]:
                diff_i = i + size - noisy_image.shape[0]
                if (j+size) > noisy_image.shape[1]:
                    diff_j = j + size - noisy_image.shape[1]
                    neighborhood = noisy_image[i-diff_i:noisy_image.shape[0], j-diff_j:noisy_image.shape[1]]
                else:
                    neighborhood = noisy_image[i-diff_i:noisy_image.shape[0], j:j+size]
            elif (j+size) > noisy_image.shape[1]:
                diff_j = j + size - noisy_image.shape[1]
                if (i+size) > noisy_image.shape[0]:
                    diff_i = i + size - noisy_image.shape[0]
                    neighborhood = noisy_image[i-diff_i:noisy_image.shape[0], j-diff_j:noisy_image.shape[1]]
                else:
                    neighborhood = noisy_image[i:i+size, j-diff_j:noisy_image.shape[1]]
            else:
                neighborhood = noisy_image[i:i+size, j:j+size]
            median = np.median(neighborhood)
            filtered[i, j] = median
    return filtered

# %%
from sklearn.metrics import mean_squared_error
from scipy import ndimage

# set the window size
window_size = [3, 5, 7, 9]

# perform best median filtering for each image
best_windows = []

for i in range(len(noisy_images)):
    min_error = 99999999
    best_win = 0
    for j in range(len(window_size)):
        filtered_img = ndimage.median_filter(noisy_images[i], size=window_size[j])
        err = mean_squared_error(elaine_img,filtered_img)
        print(f"got error={err} for noisy image{i} with window_size={window_size[j]}")
        if err < min_error:
            min_error = err
            best_win = window_size[j]
    best_windows.append(best_win)
    
# display the filtered image
# plt.imshow(filtered_img, cmap='gray', vmin=0, vmax=255)
# plt.show()
# Out:
# got error=39.455718994140625 for noisy image0 with window_size=3
# got error=50.34526443481445 for noisy image0 with window_size=5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 13
#      11 best_win = 0
#      12 for j in range(len(window_size)):
# ---> 13     filtered_img = median_filter(noisy_images[i], size=window_size[j])
#      14     err = mean_squared_error(elaine_img,filtered_img)
#      15     print(f"got error={err} for noisy image{i} with window_size={window_size[j]}")
#
# Cell In[7], line 23, in median_filter(noisy_image, size)
#      21         else:
#      22             neighborhood = noisy_image[i:i+size, j:j+size]
# ---> 23         median = np.median(neighborhood)
#      24         filtered[i, j] = median
#      25 return filtered
#
# File <__array_function__ internals>:200, in median(*args, **kwargs)
#
# File E:\uni files\semester6\Projects\venv\lib\site-packages\numpy\lib\function_base.py:3856, in median(a, axis, out, overwrite_input, keepdims)
#    3774 @array_function_dispatch(_median_dispatcher)
#    3775 def median(a, axis=None, out=None, overwrite_input=False, keepdims=False):
#    3776     """
#    3777     Compute the median along the specified axis.
#    3778
#    (...)
#    3854
#    3855     """
# -> 3856     return _ureduce(a, func=_median, keepdims=keepdims, axis=axis, out=out,
#    3857                     overwrite_input=overwrite_input)
#
# File E:\uni files\semester6\Projects\venv\lib\site-packages\numpy\lib\function_base.py:3752, in _ureduce(a, func, keepdims, **kwargs)
#    3749             index_out = (0, ) * nd
#    3750             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3752 r = func(a, **kwargs)
#    3754 if out is not None:
#    3755     return out
#
# File E:\uni files\semester6\Projects\venv\lib\site-packages\numpy\lib\function_base.py:3887, in _median(a, axis, out, overwrite_input)
#    3885         part = a
#    3886 else:
# -> 3887     part = partition(a, kth, axis=axis)
#    3889 if part.shape == ():
#    3890     # make 0-D arrays work
#    3891     return part.item()
#
# File <__array_function__ internals>:200, in partition(*args, **kwargs)
#
# File E:\uni files\semester6\Projects\venv\lib\site-packages\numpy\core\fromnumeric.py:784, in partition(a, kth, axis, kind, order)
#     782 else:
#     783     a = asanyarray(a).copy(order="K")
# --> 784 a.partition(kth, axis=axis, kind=kind, order=order)
#     785 return a
#
# KeyboardInterrupt:

# %%
# Out:
# 39.455718994140625
